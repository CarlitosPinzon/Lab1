# %% [markdown]
# # Procesamiento de Datos a Gran Escala — Taller de Python
#
# **Cuaderno Bono: Práctico Bono 1 — Ejercicios de Funciones**
#
# | Campo | Dato |
# |---|---|
# | Nombre completo | Carlos Santiago Pinzón Caicedo |
# | Documento de identidad | 1016833911 |
# | Asignatura | Procesamiento de Datos a Gran Escala |
# | Programa | Ingeniería de Sistemas, séptimo semestre |
# | Universidad | Pontificia Universidad Javeriana |
# | Fecha | 15 de agosto de 2026 |
#
# **Descripción del autor:** Estudiante de Ingeniería de Sistemas de séptimo semestre en la Pontificia Universidad Javeriana.
#
# **Sobre este cuaderno:** Resolución de los ocho ejercicios propuestos, organizados en calentamiento, nivel 1 y nivel 2. Cada función se acompaña de sus celdas de revisión para evidenciar que devuelve el resultado esperado.
#
# ---

# %% [markdown]
# > **Nota propia:** En esta sección de calentamiento resuelvo tres funciones sencillas apoyándome en operadores de comparación, el operador módulo para saber si un número es par, y los métodos de cadena vistos en el primer cuaderno.

# %% [markdown]
# ## CALENTAMIENTO:

# %% [markdown]
# #### MENOR DE DOS PARES: Escriba una función que devuelva el menor de dos números dados *si* ambos números son pares, pero devuelva el mayor si uno o ambos números son impares
#     lesser_of_two_evens(2,4) --> 2
#     lesser_of_two_evens(2,5) --> 5

# %%
def lesser_of_two_evens(a, b):
    # Si los dos son pares devuelvo el menor, en cualquier otro caso el mayor
    if a % 2 == 0 and b % 2 == 0:
        return min(a, b)
    else:
        return max(a, b)

# %%
# Revisión
lesser_of_two_evens(2,4)
# Out:
# 2

# %%
# Revisión
lesser_of_two_evens(2,5)
# Out:
# 5

# %% [markdown]
# > **Nota propia:** Para comparar las iniciales primero separo la cadena con split(), que me devuelve una lista de palabras. Luego tomo el primer carácter de cada una con doble índice: palabras[0][0]. Paso todo a minúscula para que la comparación no dependa de si la palabra viene capitalizada.

# %% [markdown]
# #### GALLETAS DE ANIMALES: Escribir una función que toma una cadena de dos palabras y devuelve True si ambas palabras comienzan con la misma letra
#     animal_crackers('Ciudad Calor') --> True
#     animal_crackers('Lugar Frio') --> False

# %%
def animal_crackers(text):
    # Separo en palabras y comparo la primera letra de cada una
    palabras = text.split()
    return palabras[0][0].lower() == palabras[1][0].lower()

# %%
# Revisión
animal_crackers('Ciudad Calor')
# Out:
# True

# %%
# Revisión
animal_crackers('Lugar Frio')
# Out:
# False

# %% [markdown]
# #### HACE VEINTE: dados dos enteros, devuelve True si la suma de los enteros es 20 o si uno de los enteros es 20. De lo contrario, devuelve False
#
#     makes_twenty(20,10) --> True
#     makes_twenty(12,8) --> True
#     makes_twenty(2,3) --> False

# %%
def makes_twenty(n1, n2):
    # Basta con que la suma sea 20 o que alguno de los dos ya lo sea
    return n1 + n2 == 20 or n1 == 20 or n2 == 20

# %%
# Revisión
makes_twenty(20,10)
# Out:
# True

# %%
# Revisión
makes_twenty(2,3)
# Out:
# False

# %%
makes_twenty(12,8)
# Out:
# True

# %% [markdown]
# # Nivel 1

# %% [markdown]
# > **Nota propia:** En el nivel 1 combino slicing con métodos de cadena. En old_macdonald corto la palabra en dos pedazos para poder capitalizar la primera y la cuarta letra por separado, y en master_yoda invierto la lista de palabras con el paso negativo [::-1] antes de unirlas de nuevo con join().

# %% [markdown]
# #### MAYÚSCULAS: Escribir una función que haga mayúscula la primera y cuarta letra de una cadena de texto
#
#     old_macdonald('macdonald') --> MacDonald
#
# Note: `'macdonald'.capitalize()` returns `'Macdonald'`

# %%
def old_macdonald(name):
    # Uso slicing para separar la palabra y aplico capitalize a cada parte
    return name[:3].capitalize() + name[3:].capitalize()

# %%
# Check
old_macdonald('macdonald')
# Out:
# 'MacDonald'

# %% [markdown]
# #### REVERSA: Dada una oración, retornar la misma oración pero en reversa
#
#     master_yoda('I am home') --> 'home am I'
#     master_yoda('We are ready') --> 'ready are We'
#
# Note: Revisar método .join()
#
#     >>> "--".join(['a','b','c'])
#     >>> 'a--b--c'
#
# Resultado de .join():
#
#     >>> " ".join(['Hello','world'])
#     >>> "Hello world"

# %%
def master_yoda(text):
    # Separo en palabras, invierto el orden y las vuelvo a unir con espacios
    return ' '.join(text.split()[::-1])

# %%
######

# %%
# Revisión
master_yoda('I am home')
# Out:
# 'home am I'

# %%
# Revisión
master_yoda('We are ready')
# Out:
# 'ready are We'

# %% [markdown]
# # Nivel 2

# %% [markdown]
# > **Nota propia:** El nivel 2 ya requiere bucles y condiciones combinadas. En has_33 recorro hasta el penúltimo índice para poder comparar cada elemento con el siguiente sin salirme del rango. En paper_doll aprovecho que multiplicar una cadena por un número la repite. En blackjack aplico el ajuste del 11 solo cuando el total se pasa de 21, y verifico de nuevo antes de decidir si devuelvo el total o 'BUST'.

# %% [markdown]
# #### PROBLEMA 33:
#
# Dada una lista de enteros, retornar True si el arreglo tinene un  3  seguido por un  3 .
#
#     has_33([1, 3, 3]) → True
#     has_33([1, 3, 1, 3]) → False
#     has_33([3, 1, 3]) → False

# %%
def has_33(nums):
    # Recorro hasta el penúltimo elemento y comparo cada par consecutivo
    for i in range(len(nums) - 1):
        if nums[i] == 3 and nums[i + 1] == 3:
            return True
    return False

# %%
# Revisión
has_33([1, 3, 3])
# Out:
# True

# %%
# Revisión
has_33([1, 3, 1, 3])
# Out:
# False

# %%
# Revisión
has_33([3, 1, 3])
# Out:
# False

# %% [markdown]
# #### REPLICADOR: Dada una cadena, devuelve una cadena donde por cada carácter en el original hay tres caracteres REPETIDOS
#     paper_doll('Hello') --> 'HHHeeellllllooo'
#     paper_doll('Mississippi') --> 'MMMiiissssssiiippppppiii'

# %%
def paper_doll(text):
    # Voy acumulando cada carácter repetido tres veces
    resultado = ''
    for caracter in text:
        resultado += caracter * 3
    return resultado

# %%
# Check
paper_doll('Hello')
# Out:
# 'HHHeeellllllooo'

# %%
# Check
paper_doll('Mississippi')
# Out:
# 'MMMiiissssssiiissssssiiippppppiii'

# %% [markdown]
# > **Nota propia:** El enunciado indica como salida esperada `'MMMiiissssssiiippppppiii'`, pero al contar los caracteres de *Mississippi* falta un grupo en ese ejemplo. Mi resultado repite tres veces cada uno de los once caracteres de la palabra, que es lo que pide la instrucción, así que dejo la función como está y anoto la diferencia.

# %% [markdown]
# #### BLACKJACK: Dados tres enteros entre 1 y 11, si su suma es menor o igual a 21, devuelve su suma. Si su suma excede 21 *y* hay un once, reduce la suma total en 10. Finalmente, si la suma (incluso después del ajuste) excede 21, devuelve 'BUST'
#     blackjack(5,6,7) --> 18
#     blackjack(9,9,9) --> 'BUST'
#     blackjack(9,9,11) --> 19

# %%
def blackjack(a, b, c):
    total = a + b + c

    # Si me paso de 21 pero tengo un 11, lo cuento como 1 restando 10
    if total > 21 and 11 in (a, b, c):
        total = total - 10

    if total > 21:
        return 'BUST'
    return total

# %%
# Revisión
blackjack(5,6,7)
# Out:
# 18

# %%
# Revisión
blackjack(9,9,9)
# Out:
# 'BUST'

# %%
# Revisión
blackjack(9,9,11)
# Out:
# 19

# %% [markdown]
# ## Suerte!

# %% [markdown]
# ---
#
# ## Conclusiones
#
# 1. Los ejercicios integran lo visto en los cuadernos anteriores: cadenas, listas, condiciones, bucles y funciones aparecen combinados en casi todos los casos.
# 2. En varios problemas la solución más corta salió de usar métodos ya disponibles como split(), join(), min() y max(), en lugar de escribir la lógica manualmente.
# 3. Al recorrer una lista comparando elementos consecutivos hay que detener el bucle en el penúltimo índice para no salirse del rango, como ocurre en has_33.
# 4. En blackjack el orden de las verificaciones es lo que define el resultado: primero se aplica el ajuste del 11 y solo después se decide si el total sigue siendo inválido.
